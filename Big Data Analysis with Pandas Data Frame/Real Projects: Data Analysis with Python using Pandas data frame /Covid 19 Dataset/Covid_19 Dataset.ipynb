# %% [raw]
#     ~~~~~ Developed By: Muhammad Umair Habib ~~~~~

# %% [raw]
# Working on real project with Python and we will use csv file.
#
# Requirements:
#
# Q1: Show the number of confirmed deaths and recovered cases in each region.
#
# Q2:In which region maximum number of confirmed cases were recorded?
#
# Q3: In which region minimum number of deaths were recorded?
#
# Q4: How many confirmed death and recovered cases were reported for Pakistan till April 29, 2020.
#
# Q5: Remove all the records where confirmed cases are less than 10.

# %%
import pandas as pd

# %%
covid_19 = pd.read_csv("covid_19_data.csv")

# %%
covid_19
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
covid_19.shape
# Out:
# (321, 6)

# %%
# this shows the not null values in the dataset, null mean missing values. 
covid_19.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
# shows the result in Boolean
covid_19.isnull()
# Out:
#       Date  State  Region  Confirmed  Deaths  Recovered
# 0    False   True   False      False   False      False
# 1    False   True   False      False   False      False
# 2    False   True   False      False   False      False
# 3    False   True   False      False   False      False
# 4    False   True   False      False   False      False
# ..     ...    ...     ...        ...     ...        ...
# 316  False  False   False      False   False      False
# 317  False  False   False      False   False      False
# 318  False  False   False      False   False      False
# 319  False  False   False      False   False      False
# 320  False  False   False      False   False      False
#
# [321 rows x 6 columns]

# %%
#shows the null values total in each column
covid_19.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
# For visualization:
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(covid_19.isnull())
plt.show()

# %% [raw]
# Q1: Show the number of confirmed deaths and recovered cases in each region.
# for "each" word we will use groupby function.

# %%
covid_19.head(3)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702

# %%
# each group by function.
covid_19.groupby('Region').sum()
# Out:
#                          Date State  Confirmed  Deaths  Recovered
# Region
# Afghanistan         4/29/2020     0       1939      60        252
# Albania             4/29/2020     0        766      30        455
# Algeria             4/29/2020     0       3848     444       1702
# Andorra             4/29/2020     0        743      42        423
# Angola              4/29/2020     0         27       2          7
# ...                       ...   ...        ...     ...        ...
# West Bank and Gaza  4/29/2020     0        344       2         71
# Western Sahara      4/29/2020     0          6       0          5
# Yemen               4/29/2020     0          6       0          1
# Zambia              4/29/2020     0         97       3         54
# Zimbabwe            4/29/2020     0         32       4          5
#
# [187 rows x 5 columns]

# %%
covid_19.groupby('Region').sum().head(25)
# Out:
#                                                                      Date  \
# Region
# Afghanistan                                                     4/29/2020
# Albania                                                         4/29/2020
# Algeria                                                         4/29/2020
# Andorra                                                         4/29/2020
# Angola                                                          4/29/2020
# Antigua and Barbuda                                             4/29/2020
# Argentina                                                       4/29/2020
# Armenia                                                         4/29/2020
# Australia               4/29/20204/29/20204/29/20204/29/20204/29/20204...
# Austria                                                         4/29/2020
# Azerbaijan                                                      4/29/2020
# Bahamas                                                         4/29/2020
# ...

# %%
# only confirmed cases. (Alphabetically). Column names are case sensitive.
covid_19.groupby('Region')['Confirmed'].sum()
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# West Bank and Gaza     344
# Western Sahara           6
# Yemen                    6
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 187, dtype: int64

# %% [raw]
# Q2:In which region maximum number of confirmed cases were recorded?

# %%
covid_19.groupby('Region')['Confirmed'].sum().sort_values(ascending=False)
# Out:
# Region
# US                  1039909
# Spain                236899
# Italy                203591
# France               166543
# UK                   166441
#                      ...
# Mauritania                8
# Papua New Guinea          8
# Bhutan                    7
# Yemen                     6
# Western Sahara            6
# Name: Confirmed, Length: 187, dtype: int64

# %% [raw]
# Q3: In which region minimum number of deaths were recorded?

# %%
covid_19.groupby('Region').Deaths.sum().sort_values(ascending=True).head(50)
# Out:
# Region
# Cambodia                            0
# Bhutan                              0
# Dominica                            0
# Central African Republic            0
# Eritrea                             0
# Fiji                                0
# Holy See                            0
# Mozambique                          0
# Macau                               0
# Madagascar                          0
# Namibia                             0
# Mongolia                            0
# Nepal                               0
# Laos                                0
# Grenada                             0
# Papua New Guinea                    0
# Sao Tome and Principe               0
# Seychelles                          0
# South Sudan                         0
# Uganda                              0
# Yemen                               0
# Timor-Leste                         0
# Vietnam                             0
# Western Sahara                      0
# ...

# %% [raw]
# Q4: How many confirmed death and recovered cases were reported for Pakistan till April 29, 2020.

# %%
covid_19[covid_19.Region == 'Pakistan']
# Out:
#           Date State    Region  Confirmed  Deaths  Recovered
# 124  4/29/2020   NaN  Pakistan      15525     343       3425

# %% [raw]
# Q5: Remove all the records where confirmed cases are less than 10.

# %%
covid_19.head(3)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702

# %%
covid_19.Confirmed < 10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# Name: Confirmed, Length: 321, dtype: bool

# %%
# Display results in the dataframe.
covid_19[covid_19.Confirmed < 10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %% [raw]
# ~ this symbol use to remove or delete

# %%
covid_19[~(covid_19.Confirmed) < 10]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
# we check, but the data is still there.
covid_19
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
# To delete permanently use this
# covid_19 = covid_19[~(covid_19.Confirmed) < 10]

# In this way data will be deleted and your file become update.
